# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

ax = plt.gca()

btc_df = None
eth_df = None
ada_df = None

osrs_df = None
ffxiv_df = None
gtav_df = None
with open("../data/prices/crypto/BTCUSDT.csv", "r") as file:
    btc_df = pd.read_csv(file)
with open("../data/prices/crypto/ETHUSDT.csv", "r") as file:
    eth_df = pd.read_csv(file)
with open("../data/prices/crypto/ADAUSDT.csv", "r") as file:
    ada_df = pd.read_csv(file)
with open("../data/prices/OSRS.csv", "r") as file:
    osrs_df = pd.read_csv(file)
with open("../data/prices/FFXIV.csv", "r") as file:
    ffxiv_df = pd.read_csv(file)
with open("../data/prices/GTA.csv", "r") as file:
    gtav_df = pd.read_csv(file)

# %%
btc_df

# %%
osrs_df

# %%
osrs_df.plot()
# Out:
# <AxesSubplot:>

# %%
ffxiv_df.plot()
# Out:
# <AxesSubplot:>

# %%
gtav_df.plot()
# Out:
# <AxesSubplot:>

# %%
btc_df.plot()
# Out:
# <AxesSubplot:>

# %%
eth_df.plot()
# Out:
# <AxesSubplot:>

# %%
ada_df.plot()
# Out:
# <AxesSubplot:>
